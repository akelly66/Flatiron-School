# %% [markdown]
# # Obtaining Your Data - Lab

# %% [markdown]
# ## Introduction
# In this lab you'll practice your munging and transforming skills in order to load in your data to solve a regression problem.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Understand the ETL process and the steps it consists of
# * Understand the challenges of working with data from multiple sources

# %% [markdown]
# ## Task Description
#
# You just got hired by Lego! Your first project is going to be to develop a pricing algorithm to help set a target price for new lego sets that are released to market. To do this, you're first going to need to start mining the company database in order to collect the information you need to develop a model.
#
# Start by investigating the database stored in lego.db and joining the tables into a unified dataset!
#
# > **Hint:** use this sql statement to preview the tables in an unknown database:
# ```sql
# SELECT name FROM sqlite_master
#              WHERE type='table'
#              ORDER BY name;
# ```

# %%
import sqlite3
connection = sqlite3.connect('lego.db')
cur = connection.cursor()

        # Your code here

# %%
cur.execute('''SELECT name FROM sqlite_master
             WHERE type='table'
             ORDER BY name;''').fetchall()
# Out:
# [('product_details',),
#  ('product_info',),
#  ('product_pricing',),
#  ('product_reviews',)]

# %%
import pandas as pd
lego_df = pd.DataFrame(cur.execute(''' SELECT * FROM product_details
                                        JOIN product_info
                                        USING(prod_id)
                                        JOIN product_pricing
                                        USING(prod_id)
                                        JOIN product_reviews
                                        USING(prod_id);''').fetchall())
lego_df.columns = [i[0] for i in cur.description]

# %%
lego_df.head()
# Out:
#    prod_id prod_desc prod_long_desc    theme_name  ages  piece_count  \
# 0    75823      blah       blahblah  Angry Birds™  6-12          277
# 1    75822      blah       blahblah  Angry Birds™  6-12          168
# 2    75821      blah       blahblah  Angry Birds™  6-12           74
# 3    21030      blah       blahblah  Architecture   12+         1032
# 4    21035      blah       blahblah  Architecture   12+          744
#
#                          set_name country list_price  num_reviews  \
# 0           Bird Island Egg Heist      US      29.99          2.0
# 1              Piggy Plane Attack      US      19.99          2.0
# 2                Piggy Car Escape      US      12.99         11.0
# 3  United States Capitol Building      US      99.99         23.0
# 4   Solomon R. Guggenheim Museum®      US      79.99         14.0
#
#    play_star_rating review_difficulty  star_rating  val_star_rating
# 0               4.0           Average          4.5              4.0
# ...

# %%
product_info = pd.DataFrame(cur.execute('''SELECT * from product_info;''').fetchall())
product_info.columns = [i[0] for i in cur.description]
product_pricing = pd.DataFrame(cur.execute('''SELECT * FROM product_pricing;''').fetchall())
product_pricing.columns = [i[0] for i in cur.description]
product_reviews = pd.DataFrame(cur.execute('''SELECT * FROM product_reviews;''').fetchall())
product_reviews.columns = [i[0] for i in cur.description]
# Out:
#      prod_id  ages  piece_count  \
# 0        630    4+            1
# 1       2304  1½-5            1
# 2       7280  5-12            2
# 3       7281  5-12            2
# 4       7499  5-12           24
# 5       7895  5-12            8
# 6       8293  9-16           10
# 7       9843    8+            1
# 8      10214   16+         4295
# 9      10220   16+         1334
# 10     10242   16+         1077
# 11     10243   16+         2469
# 12     10246   16+         2262
# 13     10247   16+         2464
# 14     10249   12+          898
# 15     10251   16+         2382
# 16     10252   16+         1167
# 17     10253   16+         4163
# 18     10254   12+          734
# 19     10255   16+         4002
# 20     10256   16+         5923
# 21     10257   16+         2670
# 22     10258   16+         1686
# 23     10259   12+          902
# 24     10260   16+         2480
# 25     10507   2-5           52
# 26     10508   2-5          134
# 27     10572  1½-5           65
# ...

# %% [markdown]
# ## Summary
# Nice work! You're working more and more independently through the workflow and ensuring data integrity!
